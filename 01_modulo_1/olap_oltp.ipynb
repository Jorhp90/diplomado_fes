# %% [markdown]
# ## <h1 style="color:#b4b564"> Librerias </h1>

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",200)
import warnings
warnings.filterwarnings("ignore")

# %%
def completitud(df):
    comple=pd.DataFrame(df.isnull().sum())
    comple.reset_index(inplace=True)
    comple=comple.rename(columns={"index":"columna",0:"total"})
    comple["completitud"]=(1-comple["total"]/df.shape[0])*100
    comple=comple.sort_values(by="completitud",ascending=True)
    comple.reset_index(drop=True,inplace=True)
    return comple

# %% [markdown]
# ## <h1 style="color:#b4b564"> Datos </h1>

# %% [markdown]
# - **fechaOper** Fecha de transacción YYYY-MM-DD .HH.Min (12 meses)
# - **codCliente**	Código de cliente banco
# - **rangoEdad**	Rango de edad del cliente donde: Rango1 hasta Rango6 la edad se ordena ascendentemente
# - **rangoIngreso**	Rango de Ingreso del cliente donde: Rango1 hasta Rango6 la edad se ordena ascendentemente
# - **flagGenero**	Flag de género del cliente donde 1: Masculino y 0: Femenino
# - **flagLimaProvCliente**	Flag de procedencia del cliente donde 1: Lima/Callao y 0: Provincia
# - **ubigeoCliente**	Código de ubigeo (código de procedencia) del cliente
# - **codGiro**	Código de giro de transacción (rubro de consumo), el rubro puede ser: restaurantes, tiendas, hotel, etc.
# - **codEstab**	Código de establecimiento o comercio, el comercio puede ser: Tienda El av. Begonias, Cineplanet av. Izaguirre, etc.
# - **flagLimaProvEstab**	Flag de procedencia del establecimiento o comercio donde 1: Lima/Callao y 0: Provincia
# - **ubigeoEstab**	Código de ubigeo (código de procedencia) del establecimiento o comercio
# - **ctdProdAct**	Rango de cantidad de productos activos (tarjeta crédito, préstamo hipotecario, préstamo vehicular y préstamo personal) donde: Rango1 hasta Rango3 la edad se ordena ascendentemente
# - **ctdProdPas**	Rango de cantidad de productos pasivos (ahorros, fondo mutuo, cts, ahorro plazo) donde: Rango1 hasta Rango3 la edad se ordena ascendentemente
# - **ctdProdSeg**	Rango de cantidad de productos de seguros (oncologico, protección múltiple, vida, vehicular, etc.) donde: Rango1 hasta Rango4 la edad se ordena ascendentemente
# - **flagBxi**	Flag si el cliente está afiliado a banca por internet donde 1: si lo esta y 0: no lo esta
# - **saldoTcEntidad1**	Rango de saldo de tarjeta de crédito de la entidad 1 en el sistema financiero donde: Rango1 hasta Rango6 la edad se ordena ascendentemente
# - **saldoTcEntidad2**	Rango de saldo de tarjeta de crédito de la entidad 2 en el sistema financiero donde: Rango1 hasta Rango5 la edad se ordena ascendentemente
# - **saldoTcEntidad3**	Rango de saldo de tarjeta de crédito de la entidad 3 en el sistema financiero donde: Rango1 hasta Rango6 la edad se ordena ascendentemente
# - **saldoTcEntidad4**	Rango de saldo de tarjeta de crédito de la entidad 4 en el sistema financiero donde: Rango1 hasta Rango6 la edad se ordena ascendentemente
# - **ctdTrx**	Cantidad de transacción (frecuencia de consumo)
# - **rankingMonto**	Ranking de prioridad de consumo(hace refenrencia a cuanto consumio)

# %%
oltp=pd.read_csv("../datos/olap_oltp/01dataBaseTrainTrxRec.csv")
olap=pd.read_csv("../datos/olap_oltp/02dataBasePerfilRec.csv")

# %%
oltp.shape
# Out:
# (1591617, 8)

# %%
olap.shape
# Out:
# (30000, 14)

# %%
oltp
# Out:
#                    fechaOper  codCliente  codGiro  codEstab  \
# 0        2017-01-29 00:00:00        7649    138.0     43629
# 1        2016-12-01 00:00:00       24604     75.0      4326
# 2        2017-06-01 00:00:00       15289     75.0      4326
# 3        2017-09-22 00:00:00        5190    110.0     59776
# 4        2017-05-05 00:00:00       16635     75.0     31043
# ...                      ...         ...      ...       ...
# 1591612  2017-09-08 00:00:00        7404    114.0     30314
# 1591613  2017-05-21 00:00:00       12253    110.0     29035
# 1591614  2017-07-31 00:00:00       16096     75.0      4323
# 1591615  2017-05-12 00:00:00        8852    110.0     51574
# 1591616  2017-05-20 00:00:00        6652    111.0     49350
#
#          flagLimaProvEstab  ubigeoEstab  ctdTrx  ratingMonto
# 0                        1        176.0       1     0.014072
# 1                        0         81.0       1     0.001667
# 2                        0         81.0       1     0.000127
# 3                        1        156.0       1     0.001167
# 4                        0         81.0       1     0.047386
# ...                    ...          ...     ...          ...
# 1591612                  1        157.0       1     0.000901
# 1591613                  1        165.0       1     0.000706
# 1591614                  1        171.0       1     0.005984
# 1591615                  1        175.0       1     0.000613
# 1591616                  0        311.0       1     0.005270
#
# [1591617 rows x 8 columns]

# %%
olap
# Out:
#        codCliente rangoEdad rangoIngreso  flagGenero  flagLimaProvCliente  \
# 0           24041    Rango2       Rango2           1                    0
# 1            9040    Rango4       Rango6           1                    1
# 2           18233    Rango2       Rango1           1                    1
# 3            7226    Rango5       Rango3           0                    1
# 4           21617    Rango3       Rango2           1                    1
# ...           ...       ...          ...         ...                  ...
# 29995         253    Rango6       Rango2           0                    1
# 29996       13378    Rango6       Rango1           0                    1
# 29997       12503    Rango3       Rango1           1                    1
# 29998       22468    Rango5       Rango3           1                    1
# 29999        5112    Rango5       Rango1           1                    1
#
#        ubigeoCliente rangoCtdProdAct rangoCtdProdPas rangoCtdProdSeg  flagBxi  \
# 0              360.0          Rango1          Rango1          Rango1        1
# 1              260.0          Rango1          Rango1          Rango1        1
# 2              273.0          Rango1          Rango2          Rango1        1
# 3              241.0          Rango1          Rango2          Rango1        1
# 4              268.0          Rango1          Rango1          Rango1        0
# ...              ...             ...             ...             ...      ...
# 29995          271.0          Rango1          Rango3          Rango1        0
# 29996          271.0          Rango1          Rango1          Rango1        1
# 29997          255.0          Rango1          Rango2          Rango1        1
# 29998          255.0          Rango1          Rango1          Rango1        1
# 29999           80.0          Rango1          Rango3          Rango1        1
#
#       saldoTcEntidad1 saldoTcEntidad2 saldoTcEntidad3 saldoTcEntidad4
# 0                 NaN             NaN             NaN             NaN
# 1              Rango1          Rango1          Rango1          Rango1
# 2              Rango2          Rango1          Rango1          Rango1
# 3              Rango1          Rango2          Rango1          Rango2
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 29995          Rango1          Rango2          Rango1          Rango1
# 29996          Rango1          Rango1          Rango1          Rango4
# 29997          Rango1          Rango1          Rango1          Rango1
# 29998          Rango1          Rango1          Rango1          Rango1
# 29999          Rango1          Rango1          Rango1          Rango1
#
# [30000 rows x 14 columns]

# %%
oltp
# Out:
#                    fechaOper  codCliente  codGiro  codEstab  \
# 0        2017-01-29 00:00:00        7649    138.0     43629
# 1        2016-12-01 00:00:00       24604     75.0      4326
# 2        2017-06-01 00:00:00       15289     75.0      4326
# 3        2017-09-22 00:00:00        5190    110.0     59776
# 4        2017-05-05 00:00:00       16635     75.0     31043
# ...                      ...         ...      ...       ...
# 1591612  2017-09-08 00:00:00        7404    114.0     30314
# 1591613  2017-05-21 00:00:00       12253    110.0     29035
# 1591614  2017-07-31 00:00:00       16096     75.0      4323
# 1591615  2017-05-12 00:00:00        8852    110.0     51574
# 1591616  2017-05-20 00:00:00        6652    111.0     49350
#
#          flagLimaProvEstab  ubigeoEstab  ctdTrx  ratingMonto
# 0                        1        176.0       1     0.014072
# 1                        0         81.0       1     0.001667
# 2                        0         81.0       1     0.000127
# 3                        1        156.0       1     0.001167
# 4                        0         81.0       1     0.047386
# ...                    ...          ...     ...          ...
# 1591612                  1        157.0       1     0.000901
# 1591613                  1        165.0       1     0.000706
# 1591614                  1        171.0       1     0.005984
# 1591615                  1        175.0       1     0.000613
# 1591616                  0        311.0       1     0.005270
#
# [1591617 rows x 8 columns]

# %% [markdown]
# ## <h1 style="color:#b4b564"> OLAP </h1>

# %%
olap.columns=['id_codCliente', 'v_rangoEdad', 'v_rangoIngreso', 'v_flagGenero',
       'v_flagLimaProvCliente', 'v_ubigeoCliente', 'v_rangoCtdProdAct',
       'v_rangoCtdProdPas', 'v_rangoCtdProdSeg', 'v_flagBxi', 'v_saldoTcEntidad1',
       'v_saldoTcEntidad2', 'v_saldoTcEntidad3', 'v_saldoTcEntidad4']

# %%
olap.duplicated().sum()
# Out:
# 0

# %%
olap.duplicated(subset=["id_codCliente"]).sum()
# Out:
# 0

# %%
for col in olap:
    print(col)
    display(pd.DataFrame(olap[col].value_counts(1)).reset_index())
    print("\n")
# Out:
# id_codCliente
#        index  id_codCliente
# 0       2049       0.000033
# 1       2708       0.000033
# 2       8881       0.000033
# 3      10928       0.000033
# 4      21151       0.000033
# ...      ...            ...
# 29995  23841       0.000033
# 29996  21792       0.000033
# 29997  11535       0.000033
# 29998   9486       0.000033
# 29999   2047       0.000033
#
# [30000 rows x 2 columns]
# v_rangoEdad
#     index  v_rangoEdad
# 0  Rango5     0.206826
# 1  Rango6     0.186454
# 2  Rango2     0.183315
# 3  Rango3     0.168821
# 4  Rango4     0.143873
# 5  Rango1     0.110710
# v_rangoIngreso
#     index  v_rangoIngreso
# 0  Rango1        0.382886
# 1  Rango3        0.182378
# 2  Rango2        0.157741
# 3  Rango6        0.136757
# 4  Rango4        0.087553
# 5  Rango5        0.052685
# v_flagGenero
#    index  v_flagGenero
# 0      1        0.5486
# 1      0        0.4514
# v_flagLimaProvCliente
#    index  v_flagLimaProvCliente
# 0      1               0.784033
# 1      0               0.215967
# v_ubigeoCliente
#      index  v_ubigeoCliente
# 0    280.0         0.071143
# 1    275.0         0.043306
# 2    272.0         0.043206
# 3    241.0         0.035505
# 4    243.0         0.033004
# ..     ...              ...
# 413   94.0         0.000033
# 414   54.0         0.000033
# 415   93.0         0.000033
# 416  112.0         0.000033
# 417  360.0         0.000033
#
# [418 rows x 2 columns]
# v_rangoCtdProdAct
#     index  v_rangoCtdProdAct
# 0  Rango1           0.931733
# 1  Rango2           0.062200
# 2  Rango3           0.006067
# v_rangoCtdProdPas
#     index  v_rangoCtdProdPas
# 0  Rango1           0.702133
# 1  Rango2           0.266333
# 2  Rango3           0.031533
# v_rangoCtdProdSeg
#     index  v_rangoCtdProdSeg
# 0  Rango1           0.766067
# 1  Rango2           0.216567
# 2  Rango3           0.016467
# 3  Rango4           0.000900
# v_flagBxi
#    index  v_flagBxi
# 0      1     0.8195
# 1      0     0.1805
# v_saldoTcEntidad1
#     index  v_saldoTcEntidad1
# 0  Rango1           0.654492
# 1  Rango3           0.088063
# 2  Rango2           0.073428
# 3  Rango4           0.072665
# 4  Rango6           0.066641
# 5  Rango5           0.044710
# v_saldoTcEntidad2
#     index  v_saldoTcEntidad2
# 0  Rango1           0.767116
# 1  Rango2           0.098117
# 2  Rango3           0.063375
# 3  Rango5           0.040256
# 4  Rango4           0.031136
# v_saldoTcEntidad3
#     index  v_saldoTcEntidad3
# 0  Rango1           0.878850
# 1  Rango6           0.030924
# 2  Rango2           0.024222
# 3  Rango3           0.023797
# 4  Rango5           0.021973
# 5  Rango4           0.020234
# v_saldoTcEntidad4
#     index  v_saldoTcEntidad4
# 0  Rango1           0.802155
# 1  Rango2           0.046492
# 2  Rango3           0.042335
# 3  Rango6           0.041359
# 4  Rango5           0.034699
# 5  Rango4           0.032960

# %%
completitud(olap)
# Out:
#                   columna  total  completitud
# 0       v_saldoTcEntidad1   6426    78.580000
# 1       v_saldoTcEntidad2   6426    78.580000
# 2       v_saldoTcEntidad3   6426    78.580000
# 3       v_saldoTcEntidad4   6426    78.580000
# 4          v_rangoIngreso   1263    95.790000
# 5             v_rangoEdad     57    99.810000
# 6         v_ubigeoCliente      4    99.986667
# 7           id_codCliente      0   100.000000
# 8            v_flagGenero      0   100.000000
# 9   v_flagLimaProvCliente      0   100.000000
# 10      v_rangoCtdProdAct      0   100.000000
# 11      v_rangoCtdProdPas      0   100.000000
# 12      v_rangoCtdProdSeg      0   100.000000
# 13              v_flagBxi      0   100.000000

# %% [markdown]
# ## <h1 style="color:#b4b564"> OLTP </h1>

# %%
oltp.head()
# Out:
#              fechaOper  codCliente  codGiro  codEstab  flagLimaProvEstab  \
# 0  2017-01-29 00:00:00        7649    138.0     43629                  1
# 1  2016-12-01 00:00:00       24604     75.0      4326                  0
# 2  2017-06-01 00:00:00       15289     75.0      4326                  0
# 3  2017-09-22 00:00:00        5190    110.0     59776                  1
# 4  2017-05-05 00:00:00       16635     75.0     31043                  0
#
#    ubigeoEstab  ctdTrx  ratingMonto
# 0        176.0       1     0.014072
# 1         81.0       1     0.001667
# 2         81.0       1     0.000127
# 3        156.0       1     0.001167
# 4         81.0       1     0.047386

# %%
oltp.duplicated().sum()
# Out:
# 0

# %%
oltp.columns=["d_fechaOper","id_codCliente","v_codGiro","v_codEstab","v_flagLimaProvEstab","v_ubigeoEstab","c_ctdTrx","c_ratingMonto"]

# %%
completitud(oltp)
# Out:
#                columna  total  completitud
# 0            v_codGiro  92686    94.176614
# 1        v_ubigeoEstab  92686    94.176614
# 2          d_fechaOper      0   100.000000
# 3        id_codCliente      0   100.000000
# 4           v_codEstab      0   100.000000
# 5  v_flagLimaProvEstab      0   100.000000
# 6             c_ctdTrx      0   100.000000
# 7        c_ratingMonto      0   100.000000

# %%
oltp["d_fechaOper"]
# Out:
# 0          2017-01-29 00:00:00
# 1          2016-12-01 00:00:00
# 2          2017-06-01 00:00:00
# 3          2017-09-22 00:00:00
# 4          2017-05-05 00:00:00
#                   ...
# 1591612    2017-09-08 00:00:00
# 1591613    2017-05-21 00:00:00
# 1591614    2017-07-31 00:00:00
# 1591615    2017-05-12 00:00:00
# 1591616    2017-05-20 00:00:00
# Name: d_fechaOper, Length: 1591617, dtype: object

# %%
oltp["d_fechaOper"]=pd.to_datetime(oltp["d_fechaOper"])

# %%
oltp["d_fechaOper"].min()
# Out:
# Timestamp('2016-11-01 00:00:00')

# %%
oltp["d_fechaOper"].max()
# Out:
# Timestamp('2017-10-31 00:00:00')

# %%
#Número de transacciones por cliente
oltp[["id_codCliente","c_ratingMonto"]].groupby(["id_codCliente"]).count()["c_ratingMonto"].mean()
# Out:
# 53.0539

# %%
oltp[["id_codCliente","c_ratingMonto"]].groupby(["id_codCliente"]).count().describe(percentiles=np.arange(0.1,1.1,.1))
# Out:
#        c_ratingMonto
# count   30000.000000
# mean       53.053900
# std        61.829447
# min         1.000000
# 10%         9.000000
# 20%        13.000000
# 30%        18.000000
# 40%        24.000000
# 50%        31.000000
# 60%        41.000000
# 70%        55.000000
# 80%        78.000000
# 90%       125.000000
# 100%      730.000000
# max       730.000000

# %%
#Meses con más transacciones
oltp["d_fechaOper"].map(lambda x:x.month_name()).value_counts(1)
# Out:
# July         0.096457
# December     0.093796
# August       0.089826
# September    0.085834
# March        0.084836
# October      0.084801
# May          0.084296
# June         0.083979
# January      0.078718
# February     0.077480
# April        0.071175
# November     0.068800
# Name: d_fechaOper, dtype: float64

# %%
#Dia de la semana con más transacciones
oltp["d_fechaOper"].map(lambda x:x.day_name()).value_counts(1)
# Out:
# Saturday     0.174803
# Friday       0.150828
# Sunday       0.143731
# Thursday     0.136233
# Wednesday    0.135506
# Tuesday      0.133307
# Monday       0.125592
# Name: d_fechaOper, dtype: float64

# %%
oltp.describe(percentiles=np.arange(0.1,1.1,.1))
# Out:
#        v_codCliente     v_codGiro    v_codEstab  v_flagLimaProvEstab  \
# count  1.591617e+06  1.498931e+06  1.591617e+06         1.591617e+06
# mean   1.334583e+04  1.048248e+02  2.453260e+04         8.084175e-01
# std    8.493548e+03  3.920585e+01  1.990371e+04         3.935464e-01
# min    1.000000e+00  2.000000e+00  1.000000e+00         0.000000e+00
# 10%    2.236000e+03  7.200000e+01  8.320000e+02         0.000000e+00
# 20%    4.733000e+03  7.500000e+01  3.411000e+03         1.000000e+00
# 30%    7.258000e+03  7.500000e+01  7.427000e+03         1.000000e+00
# 40%    9.774000e+03  8.500000e+01  1.884500e+04         1.000000e+00
# 50%    1.258100e+04  1.080000e+02  2.266500e+04         1.000000e+00
# 60%    1.551700e+04  1.100000e+02  2.931100e+04         1.000000e+00
# 70%    1.876400e+04  1.120000e+02  3.280100e+04         1.000000e+00
# 80%    2.211200e+04  1.140000e+02  4.174800e+04         1.000000e+00
# 90%    2.571200e+04  1.630000e+02  5.072900e+04         1.000000e+00
# 100%   3.000000e+04  2.250000e+02  8.227600e+04         1.000000e+00
# max    3.000000e+04  2.250000e+02  8.227600e+04         1.000000e+00
#
#        v_ubigeoEstab      c_ctdTrx  c_ratingMonto
# count   1.498931e+06  1.591617e+06   1.591617e+06
# mean    1.747467e+02  1.072021e+00   1.318383e-02
# std     6.856421e+01  3.465646e-01   3.236438e-02
# min     2.000000e+00  1.000000e+00   2.984905e-06
# 10%     1.360000e+02  1.000000e+00   6.793478e-04
# 20%     1.470000e+02  1.000000e+00   1.261830e-03
# 30%     1.500000e+02  1.000000e+00   1.981155e-03
# 40%     1.570000e+02  1.000000e+00   2.908789e-03
# 50%     1.650000e+02  1.000000e+00   4.199563e-03
# 60%     1.660000e+02  1.000000e+00   6.089940e-03
# 70%     1.710000e+02  1.000000e+00   9.154365e-03
# 80%     1.750000e+02  1.000000e+00   1.493382e-02
# 90%     2.420000e+02  1.000000e+00   2.991611e-02
# 100%    4.350000e+02  2.900000e+01   1.000000e+00
# max     4.350000e+02  2.900000e+01   1.000000e+00

# %%
completitud(oltp)
# Out:
#                columna  total  completitud
# 0            v_codGiro  92686    94.176614
# 1        v_ubigeoEstab  92686    94.176614
# 2          d_fechaOper      0   100.000000
# 3        id_codCliente      0   100.000000
# 4           v_codEstab      0   100.000000
# 5  v_flagLimaProvEstab      0   100.000000
# 6             c_ctdTrx      0   100.000000
# 7        c_ratingMonto      0   100.000000

# %%
#oltp=oltp.dropna()

# %%
oltp["d_fechaOper"].max()
# Out:
# Timestamp('2017-10-31 00:00:00')

# %%
id_cliente=list(oltp["id_codCliente"].unique())

# %%
len(id_cliente)
# Out:
# 30000

# %% [markdown]
# ## <h1 style="color:#b4b564"> OPCION A </h1>

# %% [markdown]
# **OBJETIVO**
# - Contruir una Tabla Analitica de Datos a partir de olap y oltp para segmentar a los clientes basados en sus caracteristicas y en su comportamiento transaccional (ACTUALES)

# %%
oltp["d_fechaOper"].max()
# Out:
# Timestamp('2017-10-31 00:00:00')

# %%
#Se va a incorporar información transaccional de 7 meses atrás 
start_date = datetime.datetime(2017,3,1)
end_date = datetime.datetime(2017, 10, 1)

# %%
#Solo tomamos aquellos clientes que tuvieron alguna transaccion en estos ultimos 7 meses
data=oltp[oltp["d_fechaOper"].map(lambda x:end_date>=x>=start_date)]

# %%
data["key"]=data["d_fechaOper"].map(lambda x:"-".join([str(x.year),str(x.month)]))

# %%
data
# Out:
#         d_fechaOper  id_codCliente  v_codGiro  v_codEstab  \
# 2        2017-06-01          15289       75.0        4326
# 3        2017-09-22           5190      110.0       59776
# 4        2017-05-05          16635       75.0       31043
# 5        2017-08-28           1578       66.0       41706
# 6        2017-07-19          18185       85.0       24590
# ...             ...            ...        ...         ...
# 1591612  2017-09-08           7404      114.0       30314
# 1591613  2017-05-21          12253      110.0       29035
# 1591614  2017-07-31          16096       75.0        4323
# 1591615  2017-05-12           8852      110.0       51574
# 1591616  2017-05-20           6652      111.0       49350
#
#          v_flagLimaProvEstab  v_ubigeoEstab  c_ctdTrx  c_ratingMonto     key
# 2                          0           81.0         1       0.000127  2017-6
# 3                          1          156.0         1       0.001167  2017-9
# 4                          0           81.0         1       0.047386  2017-5
# 5                          1          176.0         1       0.019062  2017-8
# 6                          0           22.0         1       0.001747  2017-7
# ...                      ...            ...       ...            ...     ...
# 1591612                    1          157.0         1       0.000901  2017-9
# 1591613                    1          165.0         1       0.000706  2017-5
# 1591614                    1          171.0         1       0.005984  2017-7
# 1591615                    1          175.0         1       0.000613  2017-5
# 1591616                    0          311.0         1       0.005270  2017-5
#
# [954881 rows x 9 columns]

# %%
#Queremos agregar información mensual, por lo cual agrupamos las transacciones diarias a mensuales, tomando la media
#Solo se tomaran las variables de monto de consumo-rating y la frecuencia de consumo
data=data[["key","id_codCliente","c_ctdTrx","c_ratingMonto"]].groupby(["key","id_codCliente"]).mean().reset_index()

# %%
#Los meses los convertimos en variables
data=data.pivot_table(["c_ctdTrx",'c_ratingMonto'], ["id_codCliente"], 'key')

# %%
data
# Out:
#               c_ctdTrx                                                  \
# key            2017-10 2017-3 2017-4 2017-5    2017-6    2017-7 2017-8
# id_codCliente
# 1                  NaN    1.0    1.0    1.0  1.000000  1.000000    1.0
# 2                  NaN    1.0    1.0    1.0  1.090909  1.000000    1.0
# 3                  NaN    1.0    NaN    1.0  1.000000       NaN    NaN
# 4                  NaN    1.0    1.0    1.0  1.166667  1.095238    1.0
# 5                  1.0    1.0    1.0    1.0  1.000000  1.000000    NaN
# ...                ...    ...    ...    ...       ...       ...    ...
# 29996              NaN    NaN    NaN    NaN  1.000000  1.000000    1.0
# 29997              NaN    NaN    NaN    1.0  1.100000  1.000000    1.0
# 29998              NaN    NaN    NaN    1.0  1.000000  1.000000    1.0
# 29999              NaN    NaN    NaN    1.0  1.000000  1.000000    NaN
# 30000              NaN    NaN    NaN    1.0  1.000000  1.000000    1.0
#
#                         c_ratingMonto                                          \
# key              2017-9       2017-10    2017-3    2017-4    2017-5    2017-6
# id_codCliente
# 1                   NaN           NaN  0.030324  0.006212  0.038929  0.015218
# 2              1.066667           NaN  0.003015  0.004256  0.002868  0.003436
# 3              1.000000           NaN  0.011377       NaN  0.042051  0.107143
# 4              1.000000           NaN  0.002168  0.002151  0.002507  0.002794
# 5              1.000000      0.004711  0.000919  0.004432  0.022142  0.014337
# ...                 ...           ...       ...       ...       ...       ...
# 29996          1.000000           NaN       NaN       NaN       NaN  0.052892
# 29997          1.142857           NaN       NaN       NaN  0.009680  0.023787
# 29998          1.000000           NaN       NaN       NaN  0.019560  0.022005
# 29999          1.000000           NaN       NaN       NaN  0.092251  0.011070
# 30000          1.000000           NaN       NaN       NaN  0.018382  0.012255
#
#
# key              2017-7    2017-8    2017-9
# id_codCliente
# 1              0.007129  0.036963       NaN
# 2              0.002814  0.002498  0.008733
# 3                   NaN       NaN  0.041763
# 4              0.006016  0.003483  0.004876
# 5              0.085495       NaN  0.012017
# ...                 ...       ...       ...
# 29996          0.012496  0.026918  0.018570
# 29997          0.018914  0.015176  0.029595
# 29998          0.040342  0.010758  0.013855
# 29999          0.092251       NaN  0.092251
# 30000          0.031950  0.018382  0.054075
#
# [29967 rows x 16 columns]

# %%
#renombramos las columnas
data.columns=["_".join(x) for x in data.columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# 0                  1               NaN              1.0              1.0
# 1                  2               NaN              1.0              1.0
# 2                  3               NaN              1.0              NaN
# 3                  4               NaN              1.0              1.0
# 4                  5               1.0              1.0              1.0
# ...              ...               ...              ...              ...
# 29962          29996               NaN              NaN              NaN
# 29963          29997               NaN              NaN              NaN
# 29964          29998               NaN              NaN              NaN
# 29965          29999               NaN              NaN              NaN
# 29966          30000               NaN              NaN              NaN
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 0                  1.0         1.000000         1.000000              1.0
# 1                  1.0         1.090909         1.000000              1.0
# 2                  1.0         1.000000              NaN              NaN
# 3                  1.0         1.166667         1.095238              1.0
# 4                  1.0         1.000000         1.000000              NaN
# ...                ...              ...              ...              ...
# 29962              NaN         1.000000         1.000000              1.0
# 29963              1.0         1.100000         1.000000              1.0
# 29964              1.0         1.000000         1.000000              1.0
# 29965              1.0         1.000000         1.000000              NaN
# 29966              1.0         1.000000         1.000000              1.0
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# 0                  NaN                    NaN              0.030324
# 1             1.066667                    NaN              0.003015
# 2             1.000000                    NaN              0.011377
# 3             1.000000                    NaN              0.002168
# 4             1.000000               0.004711              0.000919
# ...                ...                    ...                   ...
# 29962         1.000000                    NaN                   NaN
# 29963         1.142857                    NaN                   NaN
# 29964         1.000000                    NaN                   NaN
# 29965         1.000000                    NaN                   NaN
# 29966         1.000000                    NaN                   NaN
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# 0                  0.006212              0.038929              0.015218
# 1                  0.004256              0.002868              0.003436
# 2                       NaN              0.042051              0.107143
# 3                  0.002151              0.002507              0.002794
# 4                  0.004432              0.022142              0.014337
# ...                     ...                   ...                   ...
# 29962                   NaN                   NaN              0.052892
# 29963                   NaN              0.009680              0.023787
# 29964                   NaN              0.019560              0.022005
# 29965                   NaN              0.092251              0.011070
# 29966                   NaN              0.018382              0.012255
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9
# 0                  0.007129              0.036963                   NaN
# 1                  0.002814              0.002498              0.008733
# 2                       NaN                   NaN              0.041763
# 3                  0.006016              0.003483              0.004876
# 4                  0.085495                   NaN              0.012017
# ...                     ...                   ...                   ...
# 29962              0.012496              0.026918              0.018570
# 29963              0.018914              0.015176              0.029595
# 29964              0.040342              0.010758              0.013855
# 29965              0.092251                   NaN              0.092251
# 29966              0.031950              0.018382              0.054075
#
# [29967 rows x 17 columns]

# %%
#Los clientes que no tuvieron transacciones en un determinado mes se indica que la frecuencia y monto fue cero
data=data.fillna(0)

# %%
olap.shape
# Out:
# (30000, 14)

# %%
#agregamos las caracteristicas de los clientes
df_all=data.merge(olap,on="id_codCliente",how="right")

# %%
df_all
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# 0              24041          0.000000              0.0         0.000000
# 1               9040          0.000000              1.0         1.000000
# 2              18233          0.000000              1.0         1.000000
# 3               7226          1.666667              1.0         1.133333
# 4              21617          0.000000              1.0         1.000000
# ...              ...               ...              ...              ...
# 29995            253          0.000000              2.0         1.000000
# 29996          13378          0.000000              1.0         0.000000
# 29997          12503          0.000000              1.0         0.000000
# 29998          22468          0.000000              0.0         0.000000
# 29999           5112          0.000000              1.0         1.333333
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 0             1.000000         0.000000              1.0             0.00
# 1             1.000000         1.142857              1.0             1.25
# 2             1.000000         1.000000              1.0             1.00
# 3             1.184211         1.148148              1.0             1.00
# 4             1.000000         0.000000              0.0             1.00
# ...                ...              ...              ...              ...
# 29995         1.000000         1.000000              1.0             1.00
# 29996         0.000000         1.000000              1.0             1.00
# 29997         0.000000         0.000000              1.0             1.00
# 29998         1.625000         0.000000              1.0             0.00
# 29999         1.200000         1.000000              1.0             1.00
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# 0                0.000               0.000000              0.000000
# 1                1.100               0.000000              0.009238
# 2                1.000               0.000000              0.004680
# 3                1.075               0.001319              0.002042
# 4                1.000               0.000000              0.024334
# ...                ...                    ...                   ...
# 29995            1.000               0.000000              0.035156
# 29996            1.000               0.000000              0.055504
# 29997            1.000               0.000000              0.012571
# 29998            0.000               0.000000              0.000000
# 29999            1.000               0.000000              0.008850
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# 0                  0.000000              0.040462              0.000000
# 1                  0.012988              0.011378              0.014927
# 2                  0.009059              0.014217              0.003020
# 3                  0.001630              0.002570              0.003230
# 4                  0.024105              0.010331              0.000000
# ...                     ...                   ...                   ...
# 29995              0.036186              0.001989              0.023449
# 29996              0.000000              0.000000              0.162812
# 29997              0.000000              0.000000              0.000000
# 29998              0.000000              0.032466              0.000000
# 29999              0.006413              0.006710              0.008448
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9  \
# 0                  0.075145              0.000000              0.000000
# 1                  0.011795              0.006368              0.005615
# 2                  0.015601              0.021490              0.004781
# 3                  0.001483              0.001285              0.002272
# 4                  0.000000              0.032369              0.016529
# ...                     ...                   ...                   ...
# 29995              0.001367              0.016264              0.023807
# 29996              0.013876              0.037928              0.113321
# 29997              0.004461              0.004055              0.015004
# 29998              0.021704              0.000000              0.000000
# 29999              0.004246              0.011346              0.007206
#
#       v_rangoEdad v_rangoIngreso  v_flagGenero  v_flagLimaProvCliente  \
# 0          Rango2         Rango2             1                      0
# 1          Rango4         Rango6             1                      1
# 2          Rango2         Rango1             1                      1
# 3          Rango5         Rango3             0                      1
# 4          Rango3         Rango2             1                      1
# ...           ...            ...           ...                    ...
# 29995      Rango6         Rango2             0                      1
# 29996      Rango6         Rango1             0                      1
# 29997      Rango3         Rango1             1                      1
# 29998      Rango5         Rango3             1                      1
# 29999      Rango5         Rango1             1                      1
#
#        v_ubigeoCliente v_rangoCtdProdAct v_rangoCtdProdPas v_rangoCtdProdSeg  \
# 0                360.0            Rango1            Rango1            Rango1
# 1                260.0            Rango1            Rango1            Rango1
# 2                273.0            Rango1            Rango2            Rango1
# 3                241.0            Rango1            Rango2            Rango1
# 4                268.0            Rango1            Rango1            Rango1
# ...                ...               ...               ...               ...
# 29995            271.0            Rango1            Rango3            Rango1
# 29996            271.0            Rango1            Rango1            Rango1
# 29997            255.0            Rango1            Rango2            Rango1
# 29998            255.0            Rango1            Rango1            Rango1
# 29999             80.0            Rango1            Rango3            Rango1
#
#        v_flagBxi v_saldoTcEntidad1 v_saldoTcEntidad2 v_saldoTcEntidad3  \
# 0              1               NaN               NaN               NaN
# 1              1            Rango1            Rango1            Rango1
# 2              1            Rango2            Rango1            Rango1
# 3              1            Rango1            Rango2            Rango1
# 4              0               NaN               NaN               NaN
# ...          ...               ...               ...               ...
# 29995          0            Rango1            Rango2            Rango1
# 29996          1            Rango1            Rango1            Rango1
# 29997          1            Rango1            Rango1            Rango1
# 29998          1            Rango1            Rango1            Rango1
# 29999          1            Rango1            Rango1            Rango1
#
#       v_saldoTcEntidad4
# 0                   NaN
# 1                Rango1
# 2                Rango1
# 3                Rango2
# 4                   NaN
# ...                 ...
# 29995            Rango1
# 29996            Rango4
# 29997            Rango1
# 29998            Rango1
# 29999            Rango1
#
# [30000 rows x 30 columns]

# %%
#Total de clientes que tuvieron al menos una transaccione en los ultimos 7 meses
len(data["id_codCliente"].unique())
# Out:
# 29967

# %%
#total clientes registrados
len(df_all["id_codCliente"].unique())
# Out:
# 30000

# %%
#total clientes registrados
len(olap["id_codCliente"].unique())
# Out:
# 30000

# %%
df_all.shape
# Out:
# (30000, 30)

# %%
#Clientes que no serán aptos para realizar la segmentacion, de los clientes actuales
#posibles clientes que dejaron de realizar movimientos meses atras
df_all[df_all["c_ctdTrx_2017-3"].isnull()]
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# 27             19318               NaN              NaN              NaN
# 55             28126               NaN              NaN              NaN
# 88             13437               NaN              NaN              NaN
# 98             12139               NaN              NaN              NaN
# 153             9182               NaN              NaN              NaN
# ...              ...               ...              ...              ...
# 29807           6307               NaN              NaN              NaN
# 29809          15499               NaN              NaN              NaN
# 29921          22987               NaN              NaN              NaN
# 29952          10483               NaN              NaN              NaN
# 29978          27657               NaN              NaN              NaN
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 27                 NaN              NaN              NaN              NaN
# 55                 NaN              NaN              NaN              NaN
# 88                 NaN              NaN              NaN              NaN
# 98                 NaN              NaN              NaN              NaN
# 153                NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 29807              NaN              NaN              NaN              NaN
# 29809              NaN              NaN              NaN              NaN
# 29921              NaN              NaN              NaN              NaN
# 29952              NaN              NaN              NaN              NaN
# 29978              NaN              NaN              NaN              NaN
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# 27                 NaN                    NaN                   NaN
# 55                 NaN                    NaN                   NaN
# 88                 NaN                    NaN                   NaN
# 98                 NaN                    NaN                   NaN
# 153                NaN                    NaN                   NaN
# ...                ...                    ...                   ...
# 29807              NaN                    NaN                   NaN
# 29809              NaN                    NaN                   NaN
# 29921              NaN                    NaN                   NaN
# 29952              NaN                    NaN                   NaN
# 29978              NaN                    NaN                   NaN
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# 27                      NaN                   NaN                   NaN
# 55                      NaN                   NaN                   NaN
# 88                      NaN                   NaN                   NaN
# 98                      NaN                   NaN                   NaN
# 153                     NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 29807                   NaN                   NaN                   NaN
# 29809                   NaN                   NaN                   NaN
# 29921                   NaN                   NaN                   NaN
# 29952                   NaN                   NaN                   NaN
# 29978                   NaN                   NaN                   NaN
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9  \
# 27                      NaN                   NaN                   NaN
# 55                      NaN                   NaN                   NaN
# 88                      NaN                   NaN                   NaN
# 98                      NaN                   NaN                   NaN
# 153                     NaN                   NaN                   NaN
# ...                     ...                   ...                   ...
# 29807                   NaN                   NaN                   NaN
# 29809                   NaN                   NaN                   NaN
# 29921                   NaN                   NaN                   NaN
# 29952                   NaN                   NaN                   NaN
# 29978                   NaN                   NaN                   NaN
#
#       v_rangoEdad v_rangoIngreso  v_flagGenero  v_flagLimaProvCliente  \
# 27         Rango5         Rango1             0                      1
# 55         Rango1            NaN             1                      1
# 88         Rango4         Rango1             0                      1
# 98         Rango2         Rango2             0                      1
# 153        Rango3         Rango1             0                      1
# ...           ...            ...           ...                    ...
# 29807      Rango6         Rango1             1                      1
# 29809      Rango6         Rango2             1                      0
# 29921      Rango5            NaN             0                      1
# 29952      Rango4         Rango3             1                      0
# 29978      Rango2         Rango1             1                      0
#
#        v_ubigeoCliente v_rangoCtdProdAct v_rangoCtdProdPas v_rangoCtdProdSeg  \
# 27               270.0            Rango1            Rango1            Rango2
# 55               283.0            Rango1            Rango1            Rango1
# 88               248.0            Rango1            Rango1            Rango2
# 98               263.0            Rango1            Rango2            Rango1
# 153              275.0            Rango1            Rango2            Rango1
# ...                ...               ...               ...               ...
# 29807            272.0            Rango1            Rango1            Rango1
# 29809            405.0            Rango1            Rango1            Rango1
# 29921             81.0            Rango1            Rango1            Rango1
# 29952            416.0            Rango1            Rango1            Rango1
# 29978            221.0            Rango1            Rango1            Rango1
#
#        v_flagBxi v_saldoTcEntidad1 v_saldoTcEntidad2 v_saldoTcEntidad3  \
# 27             1            Rango3            Rango1            Rango1
# 55             1               NaN               NaN               NaN
# 88             0            Rango4            Rango4            Rango1
# 98             1            Rango1            Rango1            Rango1
# 153            0            Rango3            Rango1            Rango1
# ...          ...               ...               ...               ...
# 29807          0            Rango4            Rango1            Rango5
# 29809          0            Rango3            Rango1            Rango1
# 29921          0               NaN               NaN               NaN
# 29952          1            Rango1            Rango4            Rango1
# 29978          0            Rango4            Rango1            Rango3
#
#       v_saldoTcEntidad4
# 27               Rango1
# 55                  NaN
# 88               Rango1
# 98               Rango1
# 153              Rango1
# ...                 ...
# 29807            Rango3
# 29809            Rango1
# 29921               NaN
# 29952            Rango1
# 29978            Rango1
#
# [519 rows x 30 columns]

# %%
tabla_final=df_all[~df_all["c_ctdTrx_2017-3"].isnull()]

# %%
tabla_final
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# 0              24041          0.000000              0.0         0.000000
# 1               9040          0.000000              1.0         1.000000
# 2              18233          0.000000              1.0         1.000000
# 3               7226          1.666667              1.0         1.133333
# 4              21617          0.000000              1.0         1.000000
# ...              ...               ...              ...              ...
# 29995            253          0.000000              2.0         1.000000
# 29996          13378          0.000000              1.0         0.000000
# 29997          12503          0.000000              1.0         0.000000
# 29998          22468          0.000000              0.0         0.000000
# 29999           5112          0.000000              1.0         1.333333
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 0             1.000000         0.000000              1.0             0.00
# 1             1.000000         1.142857              1.0             1.25
# 2             1.000000         1.000000              1.0             1.00
# 3             1.184211         1.148148              1.0             1.00
# 4             1.000000         0.000000              0.0             1.00
# ...                ...              ...              ...              ...
# 29995         1.000000         1.000000              1.0             1.00
# 29996         0.000000         1.000000              1.0             1.00
# 29997         0.000000         0.000000              1.0             1.00
# 29998         1.625000         0.000000              1.0             0.00
# 29999         1.200000         1.000000              1.0             1.00
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# 0                0.000               0.000000              0.000000
# 1                1.100               0.000000              0.009238
# 2                1.000               0.000000              0.004680
# 3                1.075               0.001319              0.002042
# 4                1.000               0.000000              0.024334
# ...                ...                    ...                   ...
# 29995            1.000               0.000000              0.035156
# 29996            1.000               0.000000              0.055504
# 29997            1.000               0.000000              0.012571
# 29998            0.000               0.000000              0.000000
# 29999            1.000               0.000000              0.008850
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# 0                  0.000000              0.040462              0.000000
# 1                  0.012988              0.011378              0.014927
# 2                  0.009059              0.014217              0.003020
# 3                  0.001630              0.002570              0.003230
# 4                  0.024105              0.010331              0.000000
# ...                     ...                   ...                   ...
# 29995              0.036186              0.001989              0.023449
# 29996              0.000000              0.000000              0.162812
# 29997              0.000000              0.000000              0.000000
# 29998              0.000000              0.032466              0.000000
# 29999              0.006413              0.006710              0.008448
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9  \
# 0                  0.075145              0.000000              0.000000
# 1                  0.011795              0.006368              0.005615
# 2                  0.015601              0.021490              0.004781
# 3                  0.001483              0.001285              0.002272
# 4                  0.000000              0.032369              0.016529
# ...                     ...                   ...                   ...
# 29995              0.001367              0.016264              0.023807
# 29996              0.013876              0.037928              0.113321
# 29997              0.004461              0.004055              0.015004
# 29998              0.021704              0.000000              0.000000
# 29999              0.004246              0.011346              0.007206
#
#       v_rangoEdad v_rangoIngreso  v_flagGenero  v_flagLimaProvCliente  \
# 0          Rango2         Rango2             1                      0
# 1          Rango4         Rango6             1                      1
# 2          Rango2         Rango1             1                      1
# 3          Rango5         Rango3             0                      1
# 4          Rango3         Rango2             1                      1
# ...           ...            ...           ...                    ...
# 29995      Rango6         Rango2             0                      1
# 29996      Rango6         Rango1             0                      1
# 29997      Rango3         Rango1             1                      1
# 29998      Rango5         Rango3             1                      1
# 29999      Rango5         Rango1             1                      1
#
#        v_ubigeoCliente v_rangoCtdProdAct v_rangoCtdProdPas v_rangoCtdProdSeg  \
# 0                360.0            Rango1            Rango1            Rango1
# 1                260.0            Rango1            Rango1            Rango1
# 2                273.0            Rango1            Rango2            Rango1
# 3                241.0            Rango1            Rango2            Rango1
# 4                268.0            Rango1            Rango1            Rango1
# ...                ...               ...               ...               ...
# 29995            271.0            Rango1            Rango3            Rango1
# 29996            271.0            Rango1            Rango1            Rango1
# 29997            255.0            Rango1            Rango2            Rango1
# 29998            255.0            Rango1            Rango1            Rango1
# 29999             80.0            Rango1            Rango3            Rango1
#
#        v_flagBxi v_saldoTcEntidad1 v_saldoTcEntidad2 v_saldoTcEntidad3  \
# 0              1               NaN               NaN               NaN
# 1              1            Rango1            Rango1            Rango1
# 2              1            Rango2            Rango1            Rango1
# 3              1            Rango1            Rango2            Rango1
# 4              0               NaN               NaN               NaN
# ...          ...               ...               ...               ...
# 29995          0            Rango1            Rango2            Rango1
# 29996          1            Rango1            Rango1            Rango1
# 29997          1            Rango1            Rango1            Rango1
# 29998          1            Rango1            Rango1            Rango1
# 29999          1            Rango1            Rango1            Rango1
#
#       v_saldoTcEntidad4
# 0                   NaN
# 1                Rango1
# 2                Rango1
# 3                Rango2
# 4                   NaN
# ...                 ...
# 29995            Rango1
# 29996            Rango4
# 29997            Rango1
# 29998            Rango1
# 29999            Rango1
#
# [29967 rows x 30 columns]

# %%
#Tabla lista para limpieza en caracteristicas y evaluación de missings
completitud(tabla_final)
# Out:
#                   columna  total  completitud
# 0       v_saldoTcEntidad4   6418    78.583108
# 1       v_saldoTcEntidad2   6418    78.583108
# 2       v_saldoTcEntidad1   6418    78.583108
# 3       v_saldoTcEntidad3   6418    78.583108
# 4          v_rangoIngreso   1262    95.788701
# 5             v_rangoEdad     57    99.809791
# 6         v_ubigeoCliente      4    99.986652
# 7               v_flagBxi      0   100.000000
# 8       v_rangoCtdProdSeg      0   100.000000
# 9       v_rangoCtdProdPas      0   100.000000
# 10      v_rangoCtdProdAct      0   100.000000
# 11  v_flagLimaProvCliente      0   100.000000
# 12           v_flagGenero      0   100.000000
# 13   c_ratingMonto_2017-9      0   100.000000
# 14   c_ratingMonto_2017-8      0   100.000000
# 15          id_codCliente      0   100.000000
# 16   c_ratingMonto_2017-5      0   100.000000
# 17   c_ratingMonto_2017-4      0   100.000000
# 18   c_ratingMonto_2017-3      0   100.000000
# 19  c_ratingMonto_2017-10      0   100.000000
# 20        c_ctdTrx_2017-9      0   100.000000
# 21        c_ctdTrx_2017-8      0   100.000000
# 22        c_ctdTrx_2017-7      0   100.000000
# 23        c_ctdTrx_2017-6      0   100.000000
# 24        c_ctdTrx_2017-5      0   100.000000
# 25        c_ctdTrx_2017-4      0   100.000000
# 26        c_ctdTrx_2017-3      0   100.000000
# 27       c_ctdTrx_2017-10      0   100.000000
# 28   c_ratingMonto_2017-6      0   100.000000
# 29   c_ratingMonto_2017-7      0   100.000000

# %% [markdown]
# ## <h1 style="color:#b4b564"> OPCION B </h1>

# %% [markdown]
# **OBJETIVO**
# - Contruir una Tabla Analitica de Datos a partir de olap y oltp para modelar la salida de un cliente y poder construir estrategias con anticipación para poder minimizar la tasa de churn [CONSIDERANDO SOLO CLIENTES CON ACTIVIDAD RECIENTE]

# %%
df_all=tabla_final.copy()

# %%
df_all.describe(percentiles=np.arange(0.1,1.1,.1))
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# count   29967.000000      29967.000000     29967.000000     29967.000000
# mean    15000.616478          0.155131         0.818122         0.793175
# std      8660.269616          0.409842         0.494665         0.503747
# min         1.000000          0.000000         0.000000         0.000000
# 10%      3001.600000          0.000000         0.000000         0.000000
# 20%      6000.200000          0.000000         0.000000         0.000000
# 30%      8999.800000          0.000000         1.000000         1.000000
# 40%     12001.400000          0.000000         1.000000         1.000000
# 50%     15001.000000          0.000000         1.000000         1.000000
# 60%     18000.600000          0.000000         1.000000         1.000000
# 70%     21000.200000          0.000000         1.000000         1.000000
# 80%     23996.800000          0.000000         1.000000         1.000000
# 90%     27000.400000          1.000000         1.142857         1.125000
# 100%    30000.000000         10.000000         7.000000         9.500000
# max     30000.000000         10.000000         7.000000         9.500000
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# count     29967.000000     29967.000000     29967.000000     29967.000000
# mean          0.843126         0.843514         0.881739         0.873437
# std           0.477613         0.479361         0.460437         0.466025
# min           0.000000         0.000000         0.000000         0.000000
# 10%           0.000000         0.000000         0.000000         0.000000
# 20%           0.000000         0.000000         1.000000         1.000000
# 30%           1.000000         1.000000         1.000000         1.000000
# 40%           1.000000         1.000000         1.000000         1.000000
# 50%           1.000000         1.000000         1.000000         1.000000
# 60%           1.000000         1.000000         1.000000         1.000000
# 70%           1.000000         1.000000         1.000000         1.000000
# 80%           1.000000         1.000000         1.000000         1.000000
# 90%           1.142857         1.142857         1.166667         1.150000
# 100%         13.000000         9.000000        13.000000        13.000000
# max          13.000000         9.000000        13.000000        13.000000
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# count     29967.000000           29967.000000          29967.000000
# mean          0.850515               0.002383              0.019994
# std           0.481868               0.014894              0.040957
# min           0.000000               0.000000              0.000000
# 10%           0.000000               0.000000              0.000000
# 20%           0.000000               0.000000              0.000000
# 30%           1.000000               0.000000              0.002694
# 40%           1.000000               0.000000              0.004854
# 50%           1.000000               0.000000              0.007529
# 60%           1.000000               0.000000              0.010978
# 70%           1.000000               0.000000              0.016499
# 80%           1.000000               0.000000              0.026255
# 90%           1.142857               0.002940              0.049910
# 100%         10.000000               0.804217              0.929306
# max          10.000000               0.804217              0.929306
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# count          29967.000000          29967.000000          29967.000000
# mean               0.018482              0.020945              0.020142
# std                0.039489              0.041260              0.039687
# min                0.000000              0.000000              0.000000
# 10%                0.000000              0.000000              0.000000
# 20%                0.000000              0.000000              0.000000
# 30%                0.002103              0.003200              0.003188
# 40%                0.004176              0.005368              0.005377
# 50%                0.006545              0.008169              0.008051
# 60%                0.009943              0.011919              0.011737
# 70%                0.015036              0.017771              0.017410
# 80%                0.023984              0.028150              0.027559
# 90%                0.045911              0.052716              0.050480
# 100%               0.972995              0.887701              0.976620
# max                0.972995              0.887701              0.976620
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9  \
# count          29967.000000          29967.000000          29967.000000
# mean               0.024345              0.022833              0.020904
# std                0.045094              0.044613              0.042031
# min                0.000000              0.000000              0.000000
# 10%                0.000000              0.000000              0.000000
# 20%                0.001846              0.001518              0.000000
# 30%                0.004359              0.003769              0.003224
# 40%                0.006934              0.006079              0.005375
# 50%                0.010303              0.009043              0.008065
# 60%                0.014874              0.013160              0.011888
# 70%                0.021783              0.019575              0.017765
# 80%                0.034095              0.030425              0.027972
# 90%                0.059712              0.056784              0.052361
# 100%               1.000000              0.851338              0.925998
# max                1.000000              0.851338              0.925998
#
#        v_flagGenero  v_flagLimaProvCliente  v_ubigeoCliente     v_flagBxi
# count  29967.000000           29967.000000     29963.000000  29967.000000
# mean       0.548537               0.783996       236.750292      0.819535
# std        0.497647               0.411524        78.342004      0.384581
# min        0.000000               0.000000         2.000000      0.000000
# 10%        0.000000               0.000000        79.000000      0.000000
# 20%        0.000000               0.000000       212.000000      1.000000
# 30%        0.000000               1.000000       245.000000      1.000000
# 40%        0.000000               1.000000       253.000000      1.000000
# 50%        1.000000               1.000000       258.000000      1.000000
# 60%        1.000000               1.000000       270.000000      1.000000
# 70%        1.000000               1.000000       273.000000      1.000000
# 80%        1.000000               1.000000       277.000000      1.000000
# 90%        1.000000               1.000000       282.000000      1.000000
# 100%       1.000000               1.000000       419.000000      1.000000
# max        1.000000               1.000000       419.000000      1.000000

# %%
#Restringimos los registros a solo aquellos clientes que en los ultimos seis meses han tenido movimientos en al menos tres meses
#Y evitar a aquellos que son nuevos o los que han dejado de tener movimiento tiempo atras
df_all=df_all[df_all[['c_ctdTrx_2017-10', 'c_ctdTrx_2017-3',
       'c_ctdTrx_2017-4', 'c_ctdTrx_2017-5', 'c_ctdTrx_2017-6',
       'c_ctdTrx_2017-7', 'c_ctdTrx_2017-8', 'c_ctdTrx_2017-9']].apply(lambda x:sum([y!=0 for y in x])>3,axis=1)]

# %%
df_all.shape
# Out:
# (26202, 30)

# %%
df_all[(df_all["c_ctdTrx_2017-10"]==0)&(df_all["c_ctdTrx_2017-9"]==0)]
# Out:
#        id_codCliente  c_ctdTrx_2017-10  c_ctdTrx_2017-3  c_ctdTrx_2017-4  \
# 7               2486               0.0         0.000000         2.000000
# 14             29390               0.0         1.000000         1.000000
# 22             17221               0.0         0.000000         1.000000
# 30             20314               0.0         1.000000         0.000000
# 34             25195               0.0         1.000000         1.000000
# ...              ...               ...              ...              ...
# 29954           3064               0.0         1.000000         1.000000
# 29955          22084               0.0         1.000000         0.000000
# 29963          10674               0.0         1.333333         1.000000
# 29979          13936               0.0         1.000000         1.000000
# 29993          26733               0.0         1.000000         1.333333
#
#        c_ctdTrx_2017-5  c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 7                  1.0              0.0         1.333333              1.0
# 14                 0.0              0.0         1.000000              1.0
# 22                 1.0              1.0         1.333333              0.0
# 30                 1.0              1.0         1.200000              0.0
# 34                 1.0              0.0         1.000000              0.0
# ...                ...              ...              ...              ...
# 29954              1.0              1.0         1.000000              1.0
# 29955              1.0              0.0         1.000000              1.0
# 29963              1.0              0.0         1.000000              1.0
# 29979              1.0              0.0         1.000000              1.0
# 29993              1.0              1.0         1.000000              1.0
#
#        c_ctdTrx_2017-9  c_ratingMonto_2017-10  c_ratingMonto_2017-3  \
# 7                  0.0                    0.0              0.000000
# 14                 0.0                    0.0              0.038552
# 22                 0.0                    0.0              0.000000
# 30                 0.0                    0.0              0.032530
# 34                 0.0                    0.0              0.084092
# ...                ...                    ...                   ...
# 29954              0.0                    0.0              0.014786
# 29955              0.0                    0.0              0.009010
# 29963              0.0                    0.0              0.021842
# 29979              0.0                    0.0              0.064286
# 29993              0.0                    0.0              0.015407
#
#        c_ratingMonto_2017-4  c_ratingMonto_2017-5  c_ratingMonto_2017-6  \
# 7                  0.109489              0.033629              0.000000
# 14                 0.022817              0.000000              0.000000
# 22                 0.051402              0.032043              0.133511
# 30                 0.000000              0.073194              0.011573
# 34                 0.088101              0.009103              0.000000
# ...                     ...                   ...                   ...
# 29954              0.020109              0.011374              0.009099
# 29955              0.000000              0.003604              0.000000
# 29963              0.022080              0.020655              0.000000
# 29979              0.092857              0.028571              0.000000
# 29993              0.047356              0.010704              0.014110
#
#        c_ratingMonto_2017-7  c_ratingMonto_2017-8  c_ratingMonto_2017-9  \
# 7                  0.147636              0.042101                   0.0
# 14                 0.052242              0.022817                   0.0
# 22                 0.105919              0.000000                   0.0
# 30                 0.024711              0.000000                   0.0
# 34                 0.090377              0.000000                   0.0
# ...                     ...                   ...                   ...
# 29954              0.009099              0.009164                   0.0
# 29955              0.023214              0.006693                   0.0
# 29963              0.081197              0.026353                   0.0
# 29979              0.021429              0.050000                   0.0
# 29993              0.028414              0.026273                   0.0
#
#       v_rangoEdad v_rangoIngreso  v_flagGenero  v_flagLimaProvCliente  \
# 7          Rango5         Rango1             0                      1
# 14         Rango3         Rango2             1                      1
# 22         Rango3         Rango1             1                      1
# 30         Rango5         Rango4             0                      0
# 34         Rango2         Rango1             0                      1
# ...           ...            ...           ...                    ...
# 29954      Rango6         Rango2             1                      1
# 29955      Rango3         Rango2             0                      1
# 29963      Rango4         Rango1             0                      1
# 29979      Rango2         Rango1             1                      1
# 29993      Rango2         Rango2             1                      0
#
#        v_ubigeoCliente v_rangoCtdProdAct v_rangoCtdProdPas v_rangoCtdProdSeg  \
# 7                241.0            Rango1            Rango1            Rango1
# 14               273.0            Rango1            Rango1            Rango1
# 22               273.0            Rango1            Rango1            Rango1
# 30                88.0            Rango1            Rango2            Rango1
# 34               272.0            Rango1            Rango1            Rango1
# ...                ...               ...               ...               ...
# 29954             81.0            Rango1            Rango1            Rango1
# 29955            246.0            Rango1            Rango1            Rango2
# 29963            246.0            Rango1            Rango1            Rango1
# 29979             81.0            Rango1            Rango2            Rango1
# 29993             60.0            Rango1            Rango1            Rango1
#
#        v_flagBxi v_saldoTcEntidad1 v_saldoTcEntidad2 v_saldoTcEntidad3  \
# 7              1            Rango1            Rango1            Rango1
# 14             1            Rango1            Rango1            Rango1
# 22             1               NaN               NaN               NaN
# 30             1            Rango1            Rango1            Rango1
# 34             1            Rango1            Rango1            Rango1
# ...          ...               ...               ...               ...
# 29954          0            Rango1            Rango1            Rango1
# 29955          1               NaN               NaN               NaN
# 29963          0            Rango1            Rango1            Rango1
# 29979          1               NaN               NaN               NaN
# 29993          1               NaN               NaN               NaN
#
#       v_saldoTcEntidad4
# 7                Rango1
# 14               Rango1
# 22                  NaN
# 30               Rango1
# 34               Rango1
# ...                 ...
# 29954            Rango1
# 29955               NaN
# 29963            Rango1
# 29979               NaN
# 29993               NaN
#
# [3660 rows x 30 columns]

# %%
#Se considerará como estatus inactivo a las personas que no transaccionaron este mes 
#y el anterior (2017-10,2017-9)
df_all[(df_all["c_ctdTrx_2017-10"]==0)&(df_all["c_ctdTrx_2017-9"]==0)].shape[0]/df_all.shape[0]
# Out:
# 0.1396839935882757

# %%
#construimos nuestra target (0-inactivos, 1-activos)
#Tasa de evento
df_all[['c_ctdTrx_2017-10', 'c_ctdTrx_2017-9']].apply(lambda x:sum([y==0 for y in x])!=2,axis=1).value_counts(1)
# Out:
# True     0.860316
# False    0.139684
# dtype: float64

# %%
df_all["target"]=df_all[['c_ctdTrx_2017-10', 'c_ctdTrx_2017-9']].apply(lambda x:sum([y==0 for y in x])==2,axis=1)*1

# %%
df_all["target"].value_counts()
# Out:
# 0    22542
# 1     3660
# Name: target, dtype: int64

# %%
#Eliminamos aquellas variables con las cuales se construyo la target
df_all=df_all.drop(columns=['c_ctdTrx_2017-10', 'c_ctdTrx_2017-9',"c_ratingMonto_2017-10","c_ctdTrx_2017-9"])

# %%
df_all
# Out:
#        id_codCliente  c_ctdTrx_2017-3  c_ctdTrx_2017-4  c_ctdTrx_2017-5  \
# 1               9040              1.0         1.000000         1.000000
# 2              18233              1.0         1.000000         1.000000
# 3               7226              1.0         1.133333         1.184211
# 4              21617              1.0         1.000000         1.000000
# 5               9649              1.0         1.333333         1.190476
# ...              ...              ...              ...              ...
# 29994           6494              1.0         1.000000         1.333333
# 29995            253              2.0         1.000000         1.000000
# 29996          13378              1.0         0.000000         0.000000
# 29997          12503              1.0         0.000000         0.000000
# 29999           5112              1.0         1.333333         1.200000
#
#        c_ctdTrx_2017-6  c_ctdTrx_2017-7  c_ctdTrx_2017-8  \
# 1             1.142857         1.000000         1.250000
# 2             1.000000         1.000000         1.000000
# 3             1.148148         1.000000         1.000000
# 4             0.000000         0.000000         1.000000
# 5             1.000000         1.222222         1.333333
# ...                ...              ...              ...
# 29994         1.000000         1.000000         1.000000
# 29995         1.000000         1.000000         1.000000
# 29996         1.000000         1.000000         1.000000
# 29997         0.000000         1.000000         1.000000
# 29999         1.000000         1.000000         1.000000
#
#        c_ratingMonto_2017-3  c_ratingMonto_2017-4  c_ratingMonto_2017-5  \
# 1                  0.009238              0.012988              0.011378
# 2                  0.004680              0.009059              0.014217
# 3                  0.002042              0.001630              0.002570
# 4                  0.024334              0.024105              0.010331
# 5                  0.004218              0.035157              0.006545
# ...                     ...                   ...                   ...
# 29994              0.030238              0.009509              0.007322
# 29995              0.035156              0.036186              0.001989
# 29996              0.055504              0.000000              0.000000
# 29997              0.012571              0.000000              0.000000
# 29999              0.008850              0.006413              0.006710
#
#        c_ratingMonto_2017-6  c_ratingMonto_2017-7  c_ratingMonto_2017-8  \
# 1                  0.014927              0.011795              0.006368
# 2                  0.003020              0.015601              0.021490
# 3                  0.003230              0.001483              0.001285
# 4                  0.000000              0.000000              0.032369
# 5                  0.004474              0.009739              0.003184
# ...                     ...                   ...                   ...
# 29994              0.011777              0.011326              0.006792
# 29995              0.023449              0.001367              0.016264
# 29996              0.162812              0.013876              0.037928
# 29997              0.000000              0.004461              0.004055
# 29999              0.008448              0.004246              0.011346
#
#        c_ratingMonto_2017-9 v_rangoEdad v_rangoIngreso  v_flagGenero  \
# 1                  0.005615      Rango4         Rango6             1
# 2                  0.004781      Rango2         Rango1             1
# 3                  0.002272      Rango5         Rango3             0
# 4                  0.016529      Rango3         Rango2             1
# 5                  0.003426      Rango5         Rango6             1
# ...                     ...         ...            ...           ...
# 29994              0.010694      Rango5         Rango2             0
# 29995              0.023807      Rango6         Rango2             0
# 29996              0.113321      Rango6         Rango1             0
# 29997              0.015004      Rango3         Rango1             1
# 29999              0.007206      Rango5         Rango1             1
#
#        v_flagLimaProvCliente  v_ubigeoCliente v_rangoCtdProdAct  \
# 1                          1            260.0            Rango1
# 2                          1            273.0            Rango1
# 3                          1            241.0            Rango1
# 4                          1            268.0            Rango1
# 5                          1            273.0            Rango2
# ...                      ...              ...               ...
# 29994                      1            271.0            Rango1
# 29995                      1            271.0            Rango1
# 29996                      1            271.0            Rango1
# 29997                      1            255.0            Rango1
# 29999                      1             80.0            Rango1
#
#       v_rangoCtdProdPas v_rangoCtdProdSeg  v_flagBxi v_saldoTcEntidad1  \
# 1                Rango1            Rango1          1            Rango1
# 2                Rango2            Rango1          1            Rango2
# 3                Rango2            Rango1          1            Rango1
# 4                Rango1            Rango1          0               NaN
# 5                Rango2            Rango2          1            Rango2
# ...                 ...               ...        ...               ...
# 29994            Rango1            Rango1          1            Rango4
# 29995            Rango3            Rango1          0            Rango1
# 29996            Rango1            Rango1          1            Rango1
# 29997            Rango2            Rango1          1            Rango1
# 29999            Rango3            Rango1          1            Rango1
#
#       v_saldoTcEntidad2 v_saldoTcEntidad3 v_saldoTcEntidad4  target
# 1                Rango1            Rango1            Rango1       0
# 2                Rango1            Rango1            Rango1       0
# 3                Rango2            Rango1            Rango2       0
# 4                   NaN               NaN               NaN       0
# 5                Rango1            Rango1            Rango1       0
# ...                 ...               ...               ...     ...
# 29994            Rango1            Rango1            Rango1       0
# 29995            Rango2            Rango1            Rango1       0
# 29996            Rango1            Rango1            Rango4       0
# 29997            Rango1            Rango1            Rango1       0
# 29999            Rango1            Rango1            Rango1       0
#
# [26202 rows x 28 columns]

# %% [markdown]
# ## <h1 style="color:#b4b564"> OPCION C </h1>

# %% [markdown]
# **OBJETIVO**
# - EN CASO DE TENER UNA VARIABLE DE STATUS(EN ESE MES) DEL CLIENTE EN LA TABLA OLAP, Contruir una Tabla Analitica de Datos a partir de olap y oltp para modelar la salida de un cliente y poder construir estrategias con anticipación para poder minimizar la tasa de churn [CONSIDERANDO LA ULTIMA ACTIVIDAD REGISTRADA]

# %%
olap
# Out:
#        id_codCliente v_rangoEdad v_rangoIngreso  v_flagGenero  \
# 0              24041      Rango2         Rango2             1
# 1               9040      Rango4         Rango6             1
# 2              18233      Rango2         Rango1             1
# 3               7226      Rango5         Rango3             0
# 4              21617      Rango3         Rango2             1
# ...              ...         ...            ...           ...
# 29995            253      Rango6         Rango2             0
# 29996          13378      Rango6         Rango1             0
# 29997          12503      Rango3         Rango1             1
# 29998          22468      Rango5         Rango3             1
# 29999           5112      Rango5         Rango1             1
#
#        v_flagLimaProvCliente  v_ubigeoCliente v_rangoCtdProdAct  \
# 0                          0            360.0            Rango1
# 1                          1            260.0            Rango1
# 2                          1            273.0            Rango1
# 3                          1            241.0            Rango1
# 4                          1            268.0            Rango1
# ...                      ...              ...               ...
# 29995                      1            271.0            Rango1
# 29996                      1            271.0            Rango1
# 29997                      1            255.0            Rango1
# 29998                      1            255.0            Rango1
# 29999                      1             80.0            Rango1
#
#       v_rangoCtdProdPas v_rangoCtdProdSeg  v_flagBxi v_saldoTcEntidad1  \
# 0                Rango1            Rango1          1               NaN
# 1                Rango1            Rango1          1            Rango1
# 2                Rango2            Rango1          1            Rango2
# 3                Rango2            Rango1          1            Rango1
# 4                Rango1            Rango1          0               NaN
# ...                 ...               ...        ...               ...
# 29995            Rango3            Rango1          0            Rango1
# 29996            Rango1            Rango1          1            Rango1
# 29997            Rango2            Rango1          1            Rango1
# 29998            Rango1            Rango1          1            Rango1
# 29999            Rango3            Rango1          1            Rango1
#
#       v_saldoTcEntidad2 v_saldoTcEntidad3 v_saldoTcEntidad4
# 0                   NaN               NaN               NaN
# 1                Rango1            Rango1            Rango1
# 2                Rango1            Rango1            Rango1
# 3                Rango2            Rango1            Rango2
# 4                   NaN               NaN               NaN
# ...                 ...               ...               ...
# 29995            Rango2            Rango1            Rango1
# 29996            Rango1            Rango1            Rango4
# 29997            Rango1            Rango1            Rango1
# 29998            Rango1            Rango1            Rango1
# 29999            Rango1            Rango1            Rango1
#
# [30000 rows x 14 columns]

# %%
import random

# %%
olap["target"]=pd.Series(random.choices([1,0], weights=[.7, .3], k=len(olap)))

# %%
olap["target"].value_counts(1)
# Out:
# 1    0.700633
# 0    0.299367
# Name: target, dtype: float64

# %%
data=oltp.copy()

# %%
data["key"]=data["d_fechaOper"].map(lambda x:"-".join([str(x.year),str(x.month)]))

# %%
#Queremos agregar información mensual, por lo cual agrupamos las transacciones diarias a mensuales, tomando la media
#Solo se tomaran las variables de monto de consumo-rating y la frecuencia de consumo
data=data[["key","id_codCliente","c_ctdTrx","c_ratingMonto"]].groupby(["key","id_codCliente"]).mean().reset_index()

# %%
#Información mas reciente
data=data.sort_values(["id_codCliente","key"],ascending=False)

# %%
def add_month(df):
    df=df.reset_index(drop=True)
    aux=df.reindex(range(0,12), fill_value=np.nan)
    aux["id_codCliente"]=aux["id_codCliente"].fillna(method="ffill")
    aux=aux.fillna(0)
    return aux

# %%
data.shape
# Out:
# (275584, 4)

# %%
data=data.groupby('id_codCliente', group_keys=False).apply(add_month)

# %%
data.head(25)
# Out:
#         key  id_codCliente  c_ctdTrx  c_ratingMonto
# 0    2017-8            1.0  1.000000       0.036963
# 1    2017-7            1.0  1.000000       0.007129
# 2    2017-6            1.0  1.000000       0.015218
# 3    2017-5            1.0  1.000000       0.038929
# 4    2017-4            1.0  1.000000       0.006212
# 5    2017-3            1.0  1.000000       0.030324
# 6    2017-2            1.0  1.000000       0.009807
# 7    2017-1            1.0  1.000000       0.022884
# 8   2016-12            1.0  1.000000       0.017712
# 9   2016-11            1.0  1.000000       0.012931
# 10        0            1.0  0.000000       0.000000
# 11        0            1.0  0.000000       0.000000
# 0    2017-9            2.0  1.066667       0.008733
# 1    2017-8            2.0  1.000000       0.002498
# 2    2017-7            2.0  1.000000       0.002814
# 3    2017-6            2.0  1.090909       0.003436
# 4    2017-5            2.0  1.000000       0.002868
# 5    2017-4            2.0  1.000000       0.004256
# 6    2017-3            2.0  1.000000       0.003015
# 7    2017-2            2.0  1.000000       0.004821
# 8   2017-10            2.0  1.000000       0.011069
# 9    2017-1            2.0  1.125000       0.001440
# 10  2016-12            2.0  1.000000       0.002662
# 11  2016-11            2.0  1.166667       0.002839
# 0    2017-9            3.0  1.000000       0.041763

# %%
data["id_codCliente"].value_counts()
# Out:
# 17653.0    12
# 23914.0    12
# 5677.0     12
# 6754.0     12
# 1047.0     12
#            ..
# 15353.0    12
# 29579.0    12
# 4975.0     12
# 20643.0    12
# 706.0      12
# Name: id_codCliente, Length: 29631, dtype: int64

# %%
data["key"]=[f"month_{i}" for i in range(1,13)]*int(data.shape[0]/12)

# %%
data
# Out:
#          key  id_codCliente  c_ctdTrx  c_ratingMonto
# 0    month_1            1.0       1.0       0.036963
# 1    month_2            1.0       1.0       0.007129
# 2    month_3            1.0       1.0       0.015218
# 3    month_4            1.0       1.0       0.038929
# 4    month_5            1.0       1.0       0.006212
# ..       ...            ...       ...            ...
# 7    month_8        30000.0       0.0       0.000000
# 8    month_9        30000.0       0.0       0.000000
# 9   month_10        30000.0       0.0       0.000000
# 10  month_11        30000.0       0.0       0.000000
# 11  month_12        30000.0       0.0       0.000000
#
# [360000 rows x 4 columns]

# %%
data=data.pivot_table(["c_ctdTrx",'c_ratingMonto'], ["id_codCliente"], 'key')

data.columns=["_".join(x) for x in data.columns]

data.reset_index(inplace=True)

# %%
data
# Out:
#        id_codCliente  c_ctdTrx_month_1  c_ctdTrx_month_10  c_ctdTrx_month_11  \
# 0                1.0          1.000000              1.000                0.0
# 1                2.0          1.066667              1.125                1.0
# 2                3.0          1.000000              0.000                0.0
# 3                4.0          1.000000              1.000                1.0
# 4                5.0          1.000000              1.000                0.0
# ...              ...               ...                ...                ...
# 29995        29996.0          1.000000              0.000                0.0
# 29996        29997.0          1.142857              0.000                0.0
# 29997        29998.0          1.000000              0.000                0.0
# 29998        29999.0          1.000000              0.000                0.0
# 29999        30000.0          1.000000              0.000                0.0
#
#        c_ctdTrx_month_12  c_ctdTrx_month_2  c_ctdTrx_month_3  \
# 0               0.000000               1.0          1.000000
# 1               1.166667               1.0          1.000000
# 2               0.000000               1.0          1.000000
# 3               1.066667               1.0          1.095238
# 4               0.000000               1.0          1.000000
# ...                  ...               ...               ...
# 29995           0.000000               1.0          1.000000
# 29996           0.000000               1.0          1.000000
# 29997           0.000000               1.0          1.000000
# 29998           0.000000               1.0          1.000000
# 29999           0.000000               1.0          1.000000
#
#        c_ctdTrx_month_4  c_ctdTrx_month_5  c_ctdTrx_month_6  c_ctdTrx_month_7  \
# 0              1.000000          1.000000          1.000000               1.0
# 1              1.090909          1.000000          1.000000               1.0
# 2              1.000000          1.000000          1.000000               1.0
# 3              1.166667          1.000000          1.000000               1.0
# 4              1.000000          1.000000          1.000000               1.0
# ...                 ...               ...               ...               ...
# 29995          1.000000          1.285714          0.000000               0.0
# 29996          1.100000          1.000000          1.142857               0.0
# 29997          1.000000          1.000000          1.000000               0.0
# 29998          1.000000          1.000000          0.000000               0.0
# 29999          1.000000          1.000000          1.000000               0.0
#
#        c_ctdTrx_month_8  c_ctdTrx_month_9  c_ratingMonto_month_1  \
# 0              1.000000               1.0               0.036963
# 1              1.000000               1.0               0.008733
# 2              1.000000               0.0               0.041763
# 3              1.300000               1.0               0.004876
# 4              1.090909               1.0               0.012017
# ...                 ...               ...                    ...
# 29995          0.000000               0.0               0.018570
# 29996          0.000000               0.0               0.029595
# 29997          0.000000               0.0               0.013855
# 29998          0.000000               0.0               0.092251
# 29999          0.000000               0.0               0.054075
#
#        c_ratingMonto_month_10  c_ratingMonto_month_11  c_ratingMonto_month_12  \
# 0                    0.012931                0.000000                0.000000
# 1                    0.001440                0.002662                0.002839
# 2                    0.000000                0.000000                0.000000
# 3                    0.002249                0.004774                0.003082
# 4                    0.016805                0.000000                0.000000
# ...                       ...                     ...                     ...
# 29995                0.000000                0.000000                0.000000
# 29996                0.000000                0.000000                0.000000
# 29997                0.000000                0.000000                0.000000
# 29998                0.000000                0.000000                0.000000
# 29999                0.000000                0.000000                0.000000
#
#        c_ratingMonto_month_2  c_ratingMonto_month_3  c_ratingMonto_month_4  \
# 0                   0.007129               0.015218               0.038929
# 1                   0.002498               0.002814               0.003436
# 2                   0.107143               0.042051               0.011377
# 3                   0.003483               0.006016               0.002794
# 4                   0.085495               0.014337               0.022142
# ...                      ...                    ...                    ...
# 29995               0.026918               0.012496               0.052892
# 29996               0.015176               0.018914               0.023787
# 29997               0.010758               0.040342               0.022005
# 29998               0.092251               0.011070               0.092251
# 29999               0.018382               0.031950               0.012255
#
#        c_ratingMonto_month_5  c_ratingMonto_month_6  c_ratingMonto_month_7  \
# 0                   0.006212               0.030324               0.009807
# 1                   0.002868               0.004256               0.003015
# 2                   0.008353               0.018433               0.052707
# 3                   0.002507               0.002151               0.002168
# 4                   0.004432               0.000919               0.001937
# ...                      ...                    ...                    ...
# 29995               0.040105               0.000000               0.000000
# 29996               0.009680               0.034745               0.000000
# 29997               0.019560               0.015892               0.000000
# 29998               0.073801               0.000000               0.000000
# 29999               0.018382               0.068627               0.000000
#
#        c_ratingMonto_month_8  c_ratingMonto_month_9
# 0                   0.022884               0.017712
# 1                   0.004821               0.011069
# 2                   0.070853               0.000000
# 3                   0.017737               0.003091
# 4                   0.011503               0.008077
# ...                      ...                    ...
# 29995               0.000000               0.000000
# 29996               0.000000               0.000000
# 29997               0.000000               0.000000
# 29998               0.000000               0.000000
# 29999               0.000000               0.000000
#
# [30000 rows x 25 columns]

# %%
data.filter(like="c_ctd").columns
# Out:
# Index(['c_ctdTrx_month_1', 'c_ctdTrx_month_10', 'c_ctdTrx_month_11',
#        'c_ctdTrx_month_12', 'c_ctdTrx_month_2', 'c_ctdTrx_month_3',
#        'c_ctdTrx_month_4', 'c_ctdTrx_month_5', 'c_ctdTrx_month_6',
#        'c_ctdTrx_month_7', 'c_ctdTrx_month_8', 'c_ctdTrx_month_9'],
#       dtype='object')

# %%
data
# Out:
#        id_codCliente  c_ctdTrx_month_1  c_ctdTrx_month_10  c_ctdTrx_month_11  \
# 0                1.0          1.000000              1.000                0.0
# 1                2.0          1.066667              1.125                1.0
# 2                3.0          1.000000              0.000                0.0
# 3                4.0          1.000000              1.000                1.0
# 4                5.0          1.000000              1.000                0.0
# ...              ...               ...                ...                ...
# 29995        29996.0          1.000000              0.000                0.0
# 29996        29997.0          1.142857              0.000                0.0
# 29997        29998.0          1.000000              0.000                0.0
# 29998        29999.0          1.000000              0.000                0.0
# 29999        30000.0          1.000000              0.000                0.0
#
#        c_ctdTrx_month_12  c_ctdTrx_month_2  c_ctdTrx_month_3  \
# 0               0.000000               1.0          1.000000
# 1               1.166667               1.0          1.000000
# 2               0.000000               1.0          1.000000
# 3               1.066667               1.0          1.095238
# 4               0.000000               1.0          1.000000
# ...                  ...               ...               ...
# 29995           0.000000               1.0          1.000000
# 29996           0.000000               1.0          1.000000
# 29997           0.000000               1.0          1.000000
# 29998           0.000000               1.0          1.000000
# 29999           0.000000               1.0          1.000000
#
#        c_ctdTrx_month_4  c_ctdTrx_month_5  c_ctdTrx_month_6  c_ctdTrx_month_7  \
# 0              1.000000          1.000000          1.000000               1.0
# 1              1.090909          1.000000          1.000000               1.0
# 2              1.000000          1.000000          1.000000               1.0
# 3              1.166667          1.000000          1.000000               1.0
# 4              1.000000          1.000000          1.000000               1.0
# ...                 ...               ...               ...               ...
# 29995          1.000000          1.285714          0.000000               0.0
# 29996          1.100000          1.000000          1.142857               0.0
# 29997          1.000000          1.000000          1.000000               0.0
# 29998          1.000000          1.000000          0.000000               0.0
# 29999          1.000000          1.000000          1.000000               0.0
#
#        c_ctdTrx_month_8  c_ctdTrx_month_9  c_ratingMonto_month_1  \
# 0              1.000000               1.0               0.036963
# 1              1.000000               1.0               0.008733
# 2              1.000000               0.0               0.041763
# 3              1.300000               1.0               0.004876
# 4              1.090909               1.0               0.012017
# ...                 ...               ...                    ...
# 29995          0.000000               0.0               0.018570
# 29996          0.000000               0.0               0.029595
# 29997          0.000000               0.0               0.013855
# 29998          0.000000               0.0               0.092251
# 29999          0.000000               0.0               0.054075
#
#        c_ratingMonto_month_10  c_ratingMonto_month_11  c_ratingMonto_month_12  \
# 0                    0.012931                0.000000                0.000000
# 1                    0.001440                0.002662                0.002839
# 2                    0.000000                0.000000                0.000000
# 3                    0.002249                0.004774                0.003082
# 4                    0.016805                0.000000                0.000000
# ...                       ...                     ...                     ...
# 29995                0.000000                0.000000                0.000000
# 29996                0.000000                0.000000                0.000000
# 29997                0.000000                0.000000                0.000000
# 29998                0.000000                0.000000                0.000000
# 29999                0.000000                0.000000                0.000000
#
#        c_ratingMonto_month_2  c_ratingMonto_month_3  c_ratingMonto_month_4  \
# 0                   0.007129               0.015218               0.038929
# 1                   0.002498               0.002814               0.003436
# 2                   0.107143               0.042051               0.011377
# 3                   0.003483               0.006016               0.002794
# 4                   0.085495               0.014337               0.022142
# ...                      ...                    ...                    ...
# 29995               0.026918               0.012496               0.052892
# 29996               0.015176               0.018914               0.023787
# 29997               0.010758               0.040342               0.022005
# 29998               0.092251               0.011070               0.092251
# 29999               0.018382               0.031950               0.012255
#
#        c_ratingMonto_month_5  c_ratingMonto_month_6  c_ratingMonto_month_7  \
# 0                   0.006212               0.030324               0.009807
# 1                   0.002868               0.004256               0.003015
# 2                   0.008353               0.018433               0.052707
# 3                   0.002507               0.002151               0.002168
# 4                   0.004432               0.000919               0.001937
# ...                      ...                    ...                    ...
# 29995               0.040105               0.000000               0.000000
# 29996               0.009680               0.034745               0.000000
# 29997               0.019560               0.015892               0.000000
# 29998               0.073801               0.000000               0.000000
# 29999               0.018382               0.068627               0.000000
#
#        c_ratingMonto_month_8  c_ratingMonto_month_9
# 0                   0.022884               0.017712
# 1                   0.004821               0.011069
# 2                   0.070853               0.000000
# 3                   0.017737               0.003091
# 4                   0.011503               0.008077
# ...                      ...                    ...
# 29995               0.000000               0.000000
# 29996               0.000000               0.000000
# 29997               0.000000               0.000000
# 29998               0.000000               0.000000
# 29999               0.000000               0.000000
#
# [30000 rows x 25 columns]

# %%
#Restringimos los registros a solo aquellos clientes que en  10 meses 
#han tenido movimientos en al menos cinco** meses
#Y evitar a aquellos que son nuevos o los que han dejado de tener movimiento tiempo atras
df_all=data[data[['c_ctdTrx_month_10', 'c_ctdTrx_month_11',
       'c_ctdTrx_month_12', 'c_ctdTrx_month_3',
       'c_ctdTrx_month_4', 'c_ctdTrx_month_5', 'c_ctdTrx_month_6',
       'c_ctdTrx_month_7', 'c_ctdTrx_month_8', 'c_ctdTrx_month_9',"c_ctdTrx_month_1",
                 "c_ctdTrx_month_2"]].apply(lambda x:sum([y!=0 for y in x])>5,axis=1)]

# %%
data.shape
# Out:
# (30000, 25)

# %%
df_all.shape[0]/data.shape[0]
# Out:
# 0.9069666666666667

# %%
olap
# Out:
#        id_codCliente v_rangoEdad v_rangoIngreso  v_flagGenero  \
# 0              24041      Rango2         Rango2             1
# 1               9040      Rango4         Rango6             1
# 2              18233      Rango2         Rango1             1
# 3               7226      Rango5         Rango3             0
# 4              21617      Rango3         Rango2             1
# ...              ...         ...            ...           ...
# 29995            253      Rango6         Rango2             0
# 29996          13378      Rango6         Rango1             0
# 29997          12503      Rango3         Rango1             1
# 29998          22468      Rango5         Rango3             1
# 29999           5112      Rango5         Rango1             1
#
#        v_flagLimaProvCliente  v_ubigeoCliente v_rangoCtdProdAct  \
# 0                          0            360.0            Rango1
# 1                          1            260.0            Rango1
# 2                          1            273.0            Rango1
# 3                          1            241.0            Rango1
# 4                          1            268.0            Rango1
# ...                      ...              ...               ...
# 29995                      1            271.0            Rango1
# 29996                      1            271.0            Rango1
# 29997                      1            255.0            Rango1
# 29998                      1            255.0            Rango1
# 29999                      1             80.0            Rango1
#
#       v_rangoCtdProdPas v_rangoCtdProdSeg  v_flagBxi v_saldoTcEntidad1  \
# 0                Rango1            Rango1          1               NaN
# 1                Rango1            Rango1          1            Rango1
# 2                Rango2            Rango1          1            Rango2
# 3                Rango2            Rango1          1            Rango1
# 4                Rango1            Rango1          0               NaN
# ...                 ...               ...        ...               ...
# 29995            Rango3            Rango1          0            Rango1
# 29996            Rango1            Rango1          1            Rango1
# 29997            Rango2            Rango1          1            Rango1
# 29998            Rango1            Rango1          1            Rango1
# 29999            Rango3            Rango1          1            Rango1
#
#       v_saldoTcEntidad2 v_saldoTcEntidad3 v_saldoTcEntidad4  target
# 0                   NaN               NaN               NaN       1
# 1                Rango1            Rango1            Rango1       1
# 2                Rango1            Rango1            Rango1       1
# 3                Rango2            Rango1            Rango2       1
# 4                   NaN               NaN               NaN       1
# ...                 ...               ...               ...     ...
# 29995            Rango2            Rango1            Rango1       1
# 29996            Rango1            Rango1            Rango4       1
# 29997            Rango1            Rango1            Rango1       1
# 29998            Rango1            Rango1            Rango1       1
# 29999            Rango1            Rango1            Rango1       0
#
# [30000 rows x 15 columns]

# %%
#Eliminamos el movimiento mas reciente registrado 
#Para poder predecir si el siguiente mes dejará el servicio
df_all=df_all.drop(columns=["c_ctdTrx_month_1","c_ratingMonto_month_1"])

# %%
df_all=df_all.merge(olap,on="id_codCliente",how="inner")

# %%
completitud(df_all)
# Out:
#                    columna  total  completitud
# 0        v_saldoTcEntidad4   5669    79.164982
# 1        v_saldoTcEntidad3   5669    79.164982
# 2        v_saldoTcEntidad2   5669    79.164982
# 3        v_saldoTcEntidad1   5669    79.164982
# 4           v_rangoIngreso   1111    95.916792
# 5              v_rangoEdad     47    99.827263
# 6          v_ubigeoCliente      4    99.985299
# 7        v_rangoCtdProdAct      0   100.000000
# 8    c_ratingMonto_month_6      0   100.000000
# 9    v_flagLimaProvCliente      0   100.000000
# 10            v_flagGenero      0   100.000000
# 11       v_rangoCtdProdSeg      0   100.000000
# 12               v_flagBxi      0   100.000000
# 13   c_ratingMonto_month_9      0   100.000000
# 14   c_ratingMonto_month_8      0   100.000000
# 15   c_ratingMonto_month_7      0   100.000000
# 16       v_rangoCtdProdPas      0   100.000000
# 17           id_codCliente      0   100.000000
# 18   c_ratingMonto_month_5      0   100.000000
# 19   c_ratingMonto_month_3      0   100.000000
# 20       c_ctdTrx_month_10      0   100.000000
# 21       c_ctdTrx_month_11      0   100.000000
# 22       c_ctdTrx_month_12      0   100.000000
# 23        c_ctdTrx_month_2      0   100.000000
# 24        c_ctdTrx_month_3      0   100.000000
# 25        c_ctdTrx_month_4      0   100.000000
# 26        c_ctdTrx_month_5      0   100.000000
# 27        c_ctdTrx_month_6      0   100.000000
# 28        c_ctdTrx_month_7      0   100.000000
# 29        c_ctdTrx_month_8      0   100.000000
# 30        c_ctdTrx_month_9      0   100.000000
# 31  c_ratingMonto_month_10      0   100.000000
# 32  c_ratingMonto_month_11      0   100.000000
# 33  c_ratingMonto_month_12      0   100.000000
# 34   c_ratingMonto_month_2      0   100.000000
# 35   c_ratingMonto_month_4      0   100.000000
# 36                  target      0   100.000000

# %%
df_all.describe()
# Out:
#        id_codCliente  c_ctdTrx_month_10  c_ctdTrx_month_11  c_ctdTrx_month_12  \
# count   27209.000000       27209.000000       27209.000000       27209.000000
# mean    14840.954574           0.601596           0.479002           0.321869
# std      8632.841778           0.545615           0.558735           0.501472
# min         1.000000           0.000000           0.000000           0.000000
# 25%      7358.000000           0.000000           0.000000           0.000000
# 50%     14783.000000           1.000000           0.000000           0.000000
# 75%     22285.000000           1.000000           1.000000           1.000000
# max     30000.000000           7.000000          14.000000           7.272727
#
#        c_ctdTrx_month_2  c_ctdTrx_month_3  c_ctdTrx_month_4  c_ctdTrx_month_5  \
# count      27209.000000      27209.000000      27209.000000      27209.000000
# mean           1.067262          1.065906          1.065436          1.066817
# std            0.251784          0.221683          0.223083          0.245417
# min            1.000000          1.000000          1.000000          1.000000
# 25%            1.000000          1.000000          1.000000          1.000000
# 50%            1.000000          1.000000          1.000000          1.000000
# 75%            1.000000          1.000000          1.000000          1.000000
# max           13.000000          7.000000          7.000000         13.000000
#
#        c_ctdTrx_month_6  c_ctdTrx_month_7  c_ctdTrx_month_8  c_ctdTrx_month_9  \
# count      27209.000000      27209.000000      27209.000000      27209.000000
# mean           1.066571          0.950516          0.836523          0.720472
# std            0.233487          0.397179          0.486577          0.530998
# min            1.000000          0.000000          0.000000          0.000000
# 25%            1.000000          1.000000          1.000000          0.000000
# 50%            1.000000          1.000000          1.000000          1.000000
# 75%            1.000000          1.000000          1.000000          1.000000
# max            9.500000         10.500000         10.000000          9.000000
#
#        c_ratingMonto_month_10  c_ratingMonto_month_11  c_ratingMonto_month_12  \
# count            27209.000000            27209.000000            27209.000000
# mean                 0.008645                0.005851                0.002763
# std                  0.019409                0.014867                0.008568
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.002621                0.000000                0.000000
# 75%                  0.009896                0.006871                0.002433
# max                  0.756847                0.507624                0.416815
#
#        c_ratingMonto_month_2  c_ratingMonto_month_3  c_ratingMonto_month_4  \
# count           27209.000000           27209.000000           27209.000000
# mean                0.027895               0.027660               0.026654
# std                 0.044626               0.042656               0.043788
# min                 0.000025               0.000032               0.000057
# 25%                 0.006038               0.006459               0.005886
# 50%                 0.013549               0.014207               0.012939
# 75%                 0.031345               0.031849               0.029751
# max                 0.951159               0.887701               0.939926
#
#        c_ratingMonto_month_5  c_ratingMonto_month_6  c_ratingMonto_month_7  \
# count           27209.000000           27209.000000           27209.000000
# mean                0.027244               0.027395               0.021583
# std                 0.044749               0.044746               0.039743
# min                 0.000020               0.000140               0.000000
# 25%                 0.005911               0.005801               0.003830
# 50%                 0.013094               0.013153               0.009803
# 75%                 0.030069               0.030324               0.023424
# max                 0.859211               0.840336               0.819187
#
#        c_ratingMonto_month_8  c_ratingMonto_month_9  v_flagGenero  \
# count           27209.000000           27209.000000  27209.000000
# mean                0.016056               0.011847      0.547723
# std                 0.030697               0.024637      0.497726
# min                 0.000000               0.000000      0.000000
# 25%                 0.001756               0.000000      0.000000
# 50%                 0.007028               0.004686      1.000000
# 75%                 0.017848               0.013375      1.000000
# max                 0.789238               0.800681      1.000000
#
#        v_flagLimaProvCliente  v_ubigeoCliente     v_flagBxi        target
# count           27209.000000     27205.000000  27209.000000  27209.000000
# mean                0.792054       237.562838      0.826601      0.700026
# std                 0.405845        77.115362      0.378598      0.458255
# min                 0.000000         2.000000      0.000000      0.000000
# 25%                 1.000000       243.000000      1.000000      0.000000
# 50%                 1.000000       258.000000      1.000000      1.000000
# 75%                 1.000000       275.000000      1.000000      1.000000
# max                 1.000000       418.000000      1.000000      1.000000

# %%
df_all
# Out:
#        id_codCliente  c_ctdTrx_month_10  c_ctdTrx_month_11  c_ctdTrx_month_12  \
# 0                1.0              1.000                0.0           0.000000
# 1                2.0              1.125                1.0           1.166667
# 2                3.0              0.000                0.0           0.000000
# 3                4.0              1.000                1.0           1.066667
# 4                5.0              1.000                0.0           0.000000
# ...              ...                ...                ...                ...
# 27204        29993.0              0.000                0.0           0.000000
# 27205        29995.0              0.000                0.0           0.000000
# 27206        29997.0              0.000                0.0           0.000000
# 27207        29998.0              0.000                0.0           0.000000
# 27208        30000.0              0.000                0.0           0.000000
#
#        c_ctdTrx_month_2  c_ctdTrx_month_3  c_ctdTrx_month_4  c_ctdTrx_month_5  \
# 0                   1.0          1.000000          1.000000               1.0
# 1                   1.0          1.000000          1.090909               1.0
# 2                   1.0          1.000000          1.000000               1.0
# 3                   1.0          1.095238          1.166667               1.0
# 4                   1.0          1.000000          1.000000               1.0
# ...                 ...               ...               ...               ...
# 27204               1.0          1.000000          1.000000               1.0
# 27205               1.0          1.000000          1.000000               1.0
# 27206               1.0          1.000000          1.100000               1.0
# 27207               1.0          1.000000          1.000000               1.0
# 27208               1.0          1.000000          1.000000               1.0
#
#        c_ctdTrx_month_6  c_ctdTrx_month_7  c_ctdTrx_month_8  c_ctdTrx_month_9  \
# 0              1.000000               1.0          1.000000               1.0
# 1              1.000000               1.0          1.000000               1.0
# 2              1.000000               1.0          1.000000               0.0
# 3              1.000000               1.0          1.300000               1.0
# 4              1.000000               1.0          1.090909               1.0
# ...                 ...               ...               ...               ...
# 27204          1.000000               0.0          0.000000               0.0
# 27205          1.000000               0.0          0.000000               0.0
# 27206          1.142857               0.0          0.000000               0.0
# 27207          1.000000               0.0          0.000000               0.0
# 27208          1.000000               0.0          0.000000               0.0
#
#        c_ratingMonto_month_10  c_ratingMonto_month_11  c_ratingMonto_month_12  \
# 0                    0.012931                0.000000                0.000000
# 1                    0.001440                0.002662                0.002839
# 2                    0.000000                0.000000                0.000000
# 3                    0.002249                0.004774                0.003082
# 4                    0.016805                0.000000                0.000000
# ...                       ...                     ...                     ...
# 27204                0.000000                0.000000                0.000000
# 27205                0.000000                0.000000                0.000000
# 27206                0.000000                0.000000                0.000000
# 27207                0.000000                0.000000                0.000000
# 27208                0.000000                0.000000                0.000000
#
#        c_ratingMonto_month_2  c_ratingMonto_month_3  c_ratingMonto_month_4  \
# 0                   0.007129               0.015218               0.038929
# 1                   0.002498               0.002814               0.003436
# 2                   0.107143               0.042051               0.011377
# 3                   0.003483               0.006016               0.002794
# 4                   0.085495               0.014337               0.022142
# ...                      ...                    ...                    ...
# 27204               0.018325               0.027909               0.029226
# 27205               0.036478               0.003774               0.031132
# 27206               0.015176               0.018914               0.023787
# 27207               0.010758               0.040342               0.022005
# 27208               0.018382               0.031950               0.012255
#
#        c_ratingMonto_month_5  c_ratingMonto_month_6  c_ratingMonto_month_7  \
# 0                   0.006212               0.030324               0.009807
# 1                   0.002868               0.004256               0.003015
# 2                   0.008353               0.018433               0.052707
# 3                   0.002507               0.002151               0.002168
# 4                   0.004432               0.000919               0.001937
# ...                      ...                    ...                    ...
# 27204               0.027646               0.266983               0.000000
# 27205               0.020755               0.019497               0.000000
# 27206               0.009680               0.034745               0.000000
# 27207               0.019560               0.015892               0.000000
# 27208               0.018382               0.068627               0.000000
#
#        c_ratingMonto_month_8  c_ratingMonto_month_9 v_rangoEdad  \
# 0                   0.022884               0.017712      Rango6
# 1                   0.004821               0.011069      Rango6
# 2                   0.070853               0.000000      Rango6
# 3                   0.017737               0.003091      Rango6
# 4                   0.011503               0.008077      Rango6
# ...                      ...                    ...         ...
# 27204               0.000000               0.000000      Rango1
# 27205               0.000000               0.000000      Rango1
# 27206               0.000000               0.000000      Rango6
# 27207               0.000000               0.000000      Rango1
# 27208               0.000000               0.000000      Rango2
#
#       v_rangoIngreso  v_flagGenero  v_flagLimaProvCliente  v_ubigeoCliente  \
# 0             Rango5             1                      1            246.0
# 1             Rango2             1                      1            241.0
# 2             Rango5             0                      1            253.0
# 3             Rango1             1                      0            212.0
# 4             Rango1             1                      1            271.0
# ...              ...           ...                    ...              ...
# 27204         Rango1             1                      1            273.0
# 27205            NaN             0                      1            281.0
# 27206         Rango2             0                      1            270.0
# 27207         Rango1             0                      1            251.0
# 27208         Rango2             0                      1            309.0
#
#       v_rangoCtdProdAct v_rangoCtdProdPas v_rangoCtdProdSeg  v_flagBxi  \
# 0                Rango1            Rango2            Rango1          1
# 1                Rango1            Rango3            Rango1          0
# 2                Rango1            Rango2            Rango2          0
# 3                Rango1            Rango1            Rango2          0
# 4                Rango1            Rango1            Rango3          1
# ...                 ...               ...               ...        ...
# 27204            Rango1            Rango2            Rango1          1
# 27205            Rango1            Rango1            Rango1          1
# 27206            Rango1            Rango1            Rango1          1
# 27207            Rango1            Rango1            Rango1          1
# 27208            Rango1            Rango1            Rango1          1
#
#       v_saldoTcEntidad1 v_saldoTcEntidad2 v_saldoTcEntidad3 v_saldoTcEntidad4  \
# 0                Rango1            Rango1            Rango1            Rango1
# 1                Rango6            Rango1            Rango1            Rango1
# 2                Rango6            Rango2            Rango1            Rango2
# 3                Rango1            Rango1            Rango1            Rango1
# 4                Rango2            Rango1            Rango5            Rango1
# ...                 ...               ...               ...               ...
# 27204            Rango1            Rango1            Rango1            Rango1
# 27205            Rango1            Rango1            Rango1            Rango1
# 27206               NaN               NaN               NaN               NaN
# 27207               NaN               NaN               NaN               NaN
# 27208            Rango1            Rango1            Rango1            Rango1
#
#        target
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# ...       ...
# 27204       0
# 27205       1
# 27206       0
# 27207       1
# 27208       1
#
# [27209 rows x 37 columns]

# %%
d
